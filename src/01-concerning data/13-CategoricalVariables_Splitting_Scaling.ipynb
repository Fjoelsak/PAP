# %% [markdown]
# Import libaries.

# %%
import numpy as np
from sklearn import preprocessing 
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Exercise: Handling Categorial Variables

# %%
#Dataset to encode
data = np.array(["Katze", "Hund", "Hamster", "Hund", "Katze", "Hund"]).reshape(-1, 1)
print(data)

# %% [markdown]
# Label encode and one hot encode your data.

# %%
... #Encoding the data

# %% [markdown]
# # Exercise: Splitting data

# %%
#Dataset to split
X, y = np.arange(10).reshape((5, 2)), list(range(5))

print(X)	
print(y)

# %% [markdown]
# Split the data into 2/3 training data and 1/3 test data.

# %%
... #Splitting the data

# %% [markdown]
# # Exercise: Scaling

# %%
#Dataset to scale
data = np.array([[1, -10, 0],
			   [20, 0, 0.3],
			   [16, 10, 0.9]])

# %% [markdown]
# Standardiation of the dataset.

# %%
data_scaled = ...

# %% [markdown]
# Min-max scaling of the dataset.

# %%
min_max_scaler = ...
